// %% [markdown]
// # Aula 34
//
// ## For - Clássico

// %%
console.log('Linha 1');
console.log('Linha 2');
console.log('Linha 3');
console.log('Linha 4');
console.log('Linha 5');
console.log('Linha 6');
console.log('Linha 7');
console.log('Linha 8');
// Out:
// Linha 1
// Linha 2
// Linha 3
// Linha 4
// Linha 5
// Linha 6
// Linha 7
// Linha 8

// %%
for (let i = 1; i <= 8; i++){
    console.log(`Linha ${i}`);
}
// Out:
// Linha 1
// Linha 2
// Linha 3
// Linha 4
// Linha 5
// Linha 6
// Linha 7
// Linha 8

// %%
const frutas = ['Maçã', 'Pêra', 'Uva'];
for(let i = 0; i < frutas.length; i++){
    console.log(frutas[i]);
}
// Out:
// Maçã
// Pêra
// Uva
